# %%
#READ THIS:!!!!!!!!
#Read Real Stock Testing TODO List.md for more information on what to do next.

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# SETTINGS

tickers = input("Enter ticker symbols separated by commas (e.g., AAPL,MSFT): ").upper().split(',')
#User Input Start and End data taken away for testing purposes
start_date = "2025-01-01"
end_date = "2025-10-01"
#start_date = input("Enter the start date (YYYY-MM-DD): ")
#end_date = input("Enter the end date (YYYY-MM-DD): ")

#User Input for Moving Average Window Sizes taken away for testing purposes
short_window = 12
long_window = 26
#short_window = int(input("Enter the window size for short-term SMA/EMA: "))
#long_window = int(input("Enter the window size for long-term SMA/EMA: "))
use_ema_input = input("Use EMA instead of SMA? (True/False): ").strip().lower()
use_ema = (use_ema_input in ['true', 't', 'yes', 'y', 'e'])


#User Input for Starting Cash and Shares per Trade taken away for testing purposes
starting_cash = 100000
shares_per_trade = 100
#starting_cash = float(input("Enter starting capital (e.g., 100000): "))
#shares_per_trade = int(input("Enter number of shares per buy/sell (e.g., 100): "))

total_realized_profit = 0
ending_cash = starting_cash
all_results = []




def backtest_crossover(ticker):
    global total_realized_profit,ending_cash
   

    print(f"\nDownloading data for {ticker}...")
    data = yf.download(ticker, start=start_date, end=end_date)
    df = data.copy()

    if data.empty:
        print(f"No data found for {ticker}. Skipping.\n")
        return

    prices = data['Close'].squeeze()

    # Calculate moving averages
    if use_ema:
        short_ma = prices.ewm(span=short_window).mean()
        long_ma = prices.ewm(span=long_window).mean()
    else:
        short_ma = prices.rolling(window=short_window).mean()
        long_ma = prices.rolling(window=long_window).mean()

    #Calculates MACD - Testing Code
    macd = prices.ewm(span=12, adjust=False).mean() - prices.ewm(span=26, adjust=False).mean()

    # Calculates RSI
    delta = prices.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    #User Input for RSI window size taken away for testing purposes
    rsiwindow = 14
    #rsiwindow = int(input("Enter the window size for RSI calculation (e.g., 14 STD): "))
    avg_gain = gain.ewm(span=rsiwindow, adjust=False).mean()
    avg_loss = loss.ewm(span=rsiwindow, adjust=False).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    #rsi = 100 - (100/(1+gain.ewm(alpha=1/rsiwindow, adjust=False).mean()/loss.ewm(alpha=1/rsiwindow,adjust=False).mean())) 
    
    # RSI overbought/oversold levels
    rsi_overbought = 65
    rsi_oversold = 35

    #MACD Strategy TESTING CODE
    #input for MACD parameters taken away for testing purposes
    #fast_length = 12
    #slow_length = 26
    #signal_smoothing = 9
    #fast_length = int(input("Enter the fast length for MACD (e.g., 12): "))
    #slow_length = int(input("Enter the slow length for MACD (e.g., 26): ")).
    #signal_smoothing = int(input("Enter the signal smoothing for MACD (e.g., 9): "))


    #Directional Movement Index (DMI) system and, the Average Directional Index (ADX)
    up_move = df['High'].diff()
    down_move = df['Low'].shift(1) - df['Low']
    df['+DM'] = up_move.where((up_move > down_move) & (up_move > 0), 0)
    df['-DM'] = down_move.where((down_move > up_move) & (down_move > 0), 0)
    df['+DM_smoothed'] = df['+DM'].ewm(alpha=1/14, adjust=False).mean()
    df['-DM_smoothed'] = df['-DM'].ewm(alpha=1/14, adjust=False).mean()

    # Ask user if they want to use RSI filter
   #use_rsi_fliter = input("Use RSI filter for buy/sell signals? (True/False): ").strip().lower() == 'true'

    # Generate signals: Buy, Sell, Hold
    signals = ['Hold']
    for i in range(1, len(prices)):
        if short_ma.iloc[i] > long_ma.iloc[i] and short_ma.iloc[i-1] <= long_ma.iloc[i-1]:
            if rsi.iloc[i] < rsi_oversold: #or not use_rsi_fliter:  # Buy only if RSI indicates oversold
                signals.append('Strong Buy')
                print(f"ALERT: Strong Buy signal on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            else:
                signals.append('Buy')

        elif short_ma.iloc[i] < long_ma.iloc[i] and short_ma.iloc[i-1] >= long_ma.iloc[i-1]:
            if rsi.iloc[i] > rsi_overbought: #or not use_rsi_fliter:  # Sell only if RSI indicates overbought
                signals.append('Strong Sell')
                print(f"ALERT: Strong Sell signal on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            else:
                signals.append('Sell')
        else:
            signals.append('Hold')
    

    #Look back RSI check trading logic
    #User Input for Lookback period for RSI signal taken away for testing purposes
        #lookback = int(input("Enter lookback period for RSI signal (e.g., 5): "))

#Short-term: 2–3 periods — more sensitive, reacts faster, but more noise.
#Medium-term: 5–7 periods — smoother, avoids false signals from single-day spikes.
#Long-term: 10+ periods — very conservative, only catches strong moves.

    #Currently Lookback for RSI is in Days. Consider changing to minutes or Hours for more Day trading style
    lookback = 5    
    lookback_signals = ['Hold'] * len(prices)
    for i in range(lookback, len(prices)):
        recent_rsi = rsi.iloc[max(0, i-lookback):i+1]
        if rsi.iloc[i-1] >= rsi_oversold and rsi.iloc[i] < rsi_oversold:
            print(f"Lookback ALERT: Recent RSI indicates oversold on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            lookback_signals[i]='Buy Lookback RSI Confirmed'
        if rsi.iloc[i-1] <= rsi_overbought and rsi.iloc[i] > rsi_overbought:
            print(f"Lookback ALERT: Recent RSI indicates overbought on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
            lookback_signals[i]='Sell Lookback RSI Confirmed'
    
    # Reading trend of RSI for additional confirmation
    last_alert = None
    for i in range(lookback, len(prices)):
        if lookback_signals[i] == 'Buy Lookback RSI Confirmed':
            if last_alert != 'Buy' and rsi.iloc[i] > rsi.iloc[i-1]:
                print(f"Trend ALERT: RSI trending up after oversold on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
                last_alert = 'Buy'
        elif lookback_signals[i] == 'Sell Lookback RSI Confirmed':
            if last_alert != 'Sell' and rsi.iloc[i] < rsi.iloc[i-1]:
                print(f"Trend ALERT: RSI trending down after overbought on {prices.index[i].date()} at price {prices.iloc[i]:.2f}")
                last_alert = 'Sell'

    # Simulate trades
    position = 0
    cash = ending_cash
    portfolio_values = []
    buy_signals_dates = []
    buy_signals_prices = []
    sell_signals_dates = []
    sell_signals_prices = []
    buy_trades = 0
    sell_trades = 0
    profit = 0
    cost_basis = 0

    for i in range(len(prices)):
        price = prices.iloc[i]
        signal = signals[i]

        if signal == 'Buy' and position == 0:
            cost = price * shares_per_trade
            if cash >= cost:
                cash -= cost
                position = shares_per_trade
                cost_basis = price
                buy_trades += 1
                buy_signals_dates.append(prices.index[i])
                buy_signals_prices.append(price)
            else:
                # Not enough cash to buy
                signals[i] = 'Hold'

        elif signal == 'Sell' and position > 0:
            cash += price * position
            profit += (price - cost_basis) * position
            position = 0
            sell_trades += 1
            sell_signals_dates.append(prices.index[i])
            sell_signals_prices.append(price)

        # Track portfolio value each day
        portfolio_value = cash + position * price
        portfolio_values.append(portfolio_value)

    # Finalize if holding position at the end
    if position > 0:
        final_price = prices.iloc[-1]
        cash += final_price * position
        profit += (final_price - cost_basis) * position
        sell_signals_dates.append(prices.index[-1])
        sell_signals_prices.append(final_price)
        position = 0
        sell_trades += 1
        portfolio_values[-1] = cash
    total_realized_profit += profit
    ending_cash = cash

    roi_percent = (ending_cash - starting_cash) / starting_cash * 100

    all_results.append({
        'Ticker': ticker,
        'Buy Trades': buy_trades,
        'Sell Trades': sell_trades,
        'Ending Cash': cash,
        'Realized Profit': profit,
        'ROI (%)': roi_percent
    })

    # Plotting
    # Create subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8), sharex=True)

    # --- Price and MAs ---
    ax1.plot(prices.index, prices, label='Price')
    ax1.plot(prices.index, short_ma, '--', label=f'Short {"EMA" if use_ema else "SMA"} ({short_window})')
    ax1.plot(prices.index, long_ma, '--', label=f'Long {"EMA" if use_ema else "SMA"} ({long_window})')
    ax1.scatter(buy_signals_dates, buy_signals_prices, marker='^', color='green', label='Buy Signal', s=100)
    ax1.scatter(sell_signals_dates, sell_signals_prices, marker='v', color='red', label='Sell Signal', s=100)
    ax1.set_title(f"{ticker} Crossover Strategy with Soft RSI Filter")
    ax1.set_ylabel("Price ($)")
    ax1.legend()
    ax1.grid(True)

    # --- RSI ---
    ax2.plot(prices.index, rsi, label= f'RSI ({rsiwindow})', color='purple')
    ax2.axhline(rsi_overbought, color='red', linestyle='--', label=f'Overbought ({rsi_overbought})')
    ax2.axhline(rsi_oversold, color='green', linestyle='--', label=f'Oversold ({rsi_oversold})')
    ax2.set_ylabel("RSI")
    ax2.set_ylim(0, 100)
    ax2.set_xlabel("Date")
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

    # Print trade summary for this ticker
    print(f"\nSummary of trades for {ticker}:")
    print(f"Buy Trades: {buy_trades}")
    print(f"Sell Trades: {sell_trades}")
    print(f"Ending Cash: ${cash:,.2f}")
    print(f"Realized Profit: ${profit:,.2f}")



# Run strategy for each ticker
for ticker in tickers:
    backtest_crossover(ticker)

# Final summary
results_df = pd.DataFrame(all_results)
print("\nAll strategies completed.")
print("\nFinal Summary for all tickers:")
print(results_df.to_string(index=False))
print(f"\nTotal Realized Profit Across All Tickers: ${total_realized_profit:,.2f}")
print(f"Ending Cash After All Trades: ${ending_cash:,.2f}")
print("Thank you for using Quantara!")
# Out:
# C:\Users\logic\AppData\Local\Temp\ipykernel_10584\1377598251.py:46: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Downloading data for AAPL...
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-10 at price 236.01
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-16 at price 227.45
# Lookback ALERT: Recent RSI indicates overbought on 2025-02-13 at price 240.94
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-10 at price 226.92
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-03 at price 202.69
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-01 at price 212.80
# Lookback ALERT: Recent RSI indicates oversold on 2025-05-07 at price 195.77
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-13 at price 212.69
# Lookback ALERT: Recent RSI indicates oversold on 2025-05-23 at price 195.05
# Lookback ALERT: Recent RSI indicates oversold on 2025-06-13 at price 196.23
# Lookback ALERT: Recent RSI indicates oversold on 2025-06-17 at price 195.42
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-30 at price 204.94
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-08 at price 209.77
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-21 at price 212.24
# Lookback ALERT: Recent RSI indicates oversold on 2025-07-31 at price 207.33
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-07 at price 219.78
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-27 at price 230.49
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-03 at price 238.47
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-19 at price 245.50
# C:\Users\logic\AppData\Local\Temp\ipykernel_10584\1377598251.py:46: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Summary of trades for AAPL:
# Buy Trades: 4
# Sell Trades: 4
# Ending Cash: $99,196.31
# Realized Profit: $-803.69
#
# Downloading data for MSFT...
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-17 at price 426.69
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-22 at price 443.76
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-28 at price 444.76
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-30 at price 412.72
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-07 at price 407.51
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-12 at price 406.80
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-14 at price 406.20
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-24 at price 402.60
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-03 at price 387.14
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-10 at price 378.84
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-28 at price 377.49
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-03 at price 371.82
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-21 at price 357.87
# Lookback ALERT: Recent RSI indicates overbought on 2025-04-30 at price 393.89
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-27 at price 459.93
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-23 at price 485.20
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-03 at price 498.02
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-24 at price 510.04
# Lookback ALERT: Recent RSI indicates oversold on 2025-08-19 at price 508.93
# Lookback ALERT: Recent RSI indicates oversold on 2025-08-25 at price 504.26
# Lookback ALERT: Recent RSI indicates oversold on 2025-09-05 at price 495.00
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-15 at price 515.36
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-19 at price 517.93
# C:\Users\logic\AppData\Local\Temp\ipykernel_10584\1377598251.py:46: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Summary of trades for MSFT:
# Buy Trades: 3
# Sell Trades: 3
# Ending Cash: $111,455.30
# Realized Profit: $12,259.00
#
# Downloading data for NVDA...
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-13 at price 133.20
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-22 at price 147.04
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-27 at price 118.39
# Lookback ALERT: Recent RSI indicates oversold on 2025-01-31 at price 120.04
# Lookback ALERT: Recent RSI indicates overbought on 2025-02-14 at price 138.82
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-25 at price 126.60
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-27 at price 120.12
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-03 at price 114.04
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-06 at price 110.55
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-28 at price 109.66
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-03 at price 101.79
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-21 at price 96.90
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-02 at price 114.49
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-07 at price 117.05
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-27 at price 135.48
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-02 at price 137.36
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-06 at price 141.70
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-16 at price 144.68
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-18 at price 145.47
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-24 at price 147.89
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-02 at price 157.24
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-23 at price 170.77
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-04 at price 179.99
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-07 at price 180.76
# Lookback ALERT: Recent RSI indicates oversold on 2025-08-29 at price 174.17
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-22 at price 183.61
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-30 at price 186.58
# C:\Users\logic\AppData\Local\Temp\ipykernel_10584\1377598251.py:46: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Summary of trades for NVDA:
# Buy Trades: 3
# Sell Trades: 3
# Ending Cash: $115,499.40
# Realized Profit: $4,044.09
#
# Downloading data for TSLA...
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-13 at price 403.31
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-15 at price 428.22
# Lookback ALERT: Recent RSI indicates overbought on 2025-01-17 at price 426.50
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-06 at price 374.32
# Lookback ALERT: Recent RSI indicates oversold on 2025-02-21 at price 337.80
# Lookback ALERT: Recent RSI indicates oversold on 2025-03-17 at price 238.01
# Lookback ALERT: Recent RSI indicates overbought on 2025-03-25 at price 288.14
# Lookback ALERT: Recent RSI indicates oversold on 2025-04-07 at price 233.29
# Lookback ALERT: Recent RSI indicates overbought on 2025-04-25 at price 284.95
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-09 at price 298.26
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-22 at price 341.04
# Lookback ALERT: Recent RSI indicates overbought on 2025-05-27 at price 362.89
# Lookback ALERT: Recent RSI indicates oversold on 2025-06-05 at price 284.70
# Lookback ALERT: Recent RSI indicates overbought on 2025-06-23 at price 348.68
# Lookback ALERT: Recent RSI indicates oversold on 2025-07-01 at price 300.71
# Lookback ALERT: Recent RSI indicates oversold on 2025-07-07 at price 293.94
# Lookback ALERT: Recent RSI indicates overbought on 2025-07-23 at price 332.56
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-11 at price 339.03
# Lookback ALERT: Recent RSI indicates overbought on 2025-08-25 at price 346.60
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-11 at price 368.81
# Lookback ALERT: Recent RSI indicates overbought on 2025-09-26 at price 440.40
# Summary of trades for TSLA:
# Buy Trades: 3
# Sell Trades: 3
# Ending Cash: $129,651.40
# Realized Profit: $14,152.00
#
# All strategies completed.
#
# Final Summary for all tickers:
# Ticker  Buy Trades  Sell Trades   Ending Cash  Realized Profit   ROI (%)
#   AAPL           4            4  99196.307373      -803.692627 -0.803693
#   MSFT           3            3 111455.303955     12258.996582 11.455304
#   NVDA           3            3 115499.396515      4044.092560 15.499397
#   TSLA           3            3 129651.396942     14152.000427 29.651397
#
# Total Realized Profit Across All Tickers: $29,651.40
# Ending Cash After All Trades: $129,651.40
# Thank you for using Quantara!

# %%
# Calculate True Range (TR) and its smoothed version for ADX calculation more work need to be done here
#also need to know wtf i just did


#df['TR'] = pd.concat([df['High'] - df['Low'], 
 #                     (df['High'] - df['Close'].shift(1)).abs(), 
  #                    (df['Low'] - df['Close'].shift(1)).abs()], axis=1).max(axis=1)
#df['TR_smoothed'] = df['TR'].ewm(alpha=1/14, adjust=False).mean()
#f['+DI'] = 100 * (df['+DM_smoothed'] / df['TR_smoothed'])
#df['-DI'] = 100 * (df['-DM_smoothed'] / df['TR_smoothed'])
#df['DX'] = 100 * (df['+DI'] - df['-DI']).abs() / (df['+DI'] + df['-DI'])
#df['ADX'] = df['DX'].ewm(alpha=1/14, adjust=False).mean()
#ADX above 25 indicates a strong trend, while below 20 suggests a weak trend.
#The +DI and -DI lines can be used to generate buy/sell signals. A buy signal occurs when +DI crosses above -DI, and a sell signal occurs when -DI crosses above +DI.
#The ADX itself does not indicate trend direction, only trend strength.
# Consider integrating these indicators into the existing strategy for enhanced decision-making.
# Consider integrating these indicators into the existing strategy for enhanced decision-making.
